# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score
import xgboost as xgb
import optuna
from google.colab import drive


# Load the data
data = pd.read_csv("/content/spam_email.csv")

# Preprocess the data
data['label'] = (data['label'] == 'Spam').astype(int)
data['text'] = data['text'].fillna('')

# Split the data
X_train, X_test, y_train, y_test = train_test_split(data['text'], data['label'], test_size=0.2, random_state=42)

# TF-IDF Vectorization
tfidf = TfidfVectorizer(max_features=1000)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# Convert to DMatrix for XGBoost
dtrain = xgb.DMatrix(X_train_tfidf, label=y_train)
dtest = xgb.DMatrix(X_test_tfidf, label=y_test)

# Define the objective function for Optuna
def objective(trial):
    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 7),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
        'n_estimators': trial.suggest_int('n_estimators', 50, 200),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 5),
        'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
        'tree_method': 'gpu_hist',  # Use GPU acceleration
        'gpu_id': 0
    }

    model = xgb.train(params, dtrain, num_boost_round=100, evals=[(dtest, 'test')], early_stopping_rounds=10, verbose_eval=False)
    preds = model.predict(dtest)
    return 1 - accuracy_score(y_test, preds > 0.5)

# Optimize hyperparameters using Optuna
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

print('Number of finished trials:', len(study.trials))
print('Best trial:')
trial = study.best_trial

print('  Value: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))

# Train the final model with the best parameters
best_params = study.best_params
best_model = xgb.train(best_params, dtrain, num_boost_round=100)

# Make predictions
train_preds = best_model.predict(dtrain)
test_preds = best_model.predict(dtest)

# Calculate accuracies
train_accuracy = accuracy_score(y_train, train_preds > 0.5)
test_accuracy = accuracy_score(y_test, test_preds > 0.5)

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Testing Accuracy: {test_accuracy:.4f}")

# Function to classify new emails
def classify_email(email_text):
    email_tfidf = tfidf.transform([email_text])
    email_dmatrix = xgb.DMatrix(email_tfidf)
    prediction = best_model.predict(email_dmatrix)[0]
    return "Spam" if prediction > 0.5 else "Ham"

# Test the classifier with some example emails
example_emails = [
    "Get rich quick! Buy our amazing product now!",
    "Hi John, can we reschedule our meeting to next week?",
    "Congratulations! You've won a free iPhone. Click here to claim.",
    "Please find attached the report for Q2 sales figures."
]

for email in example_emails:
    print(f"Email: {email}")
    print(f"Classification: {classify_email(email)}\n")
# Out:
# [I 2024-09-05 01:36:47,116] A new study created in memory with name: no-name-d2367851-4d17-4cbe-973a-c19c629e67a5
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:36:47] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:36:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:36:51] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:36:51,803] Trial 0 finished with value: 0.047329189342549816 and parameters: {'max_depth': 7, 'learning_rate': 0.13363584613867385, 'n_estimators': 176, 'min_child_weight': 1, 'subsample': 0.7143566878736343, 'colsample_bytree': 0.8454838011324011}. Best is trial 0 with value: 0.047329189342549816.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:36:51] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:36:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:36:53] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:36:53,953] Trial 1 finished with value: 0.06424905212658949 and parameters: {'max_depth': 5, 'learning_rate': 0.09844135666835542, 'n_estimators': 55, 'min_child_weight': 5, 'subsample': 0.8818219566041938, 'colsample_bytree': 0.6954071412598145}. Best is trial 0 with value: 0.047329189342549816.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:36:53] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:36:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:36:57] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:36:57,465] Trial 2 finished with value: 0.10077119496530917 and parameters: {'max_depth': 6, 'learning_rate': 0.018291822362372256, 'n_estimators': 101, 'min_child_weight': 4, 'subsample': 0.8288246676110927, 'colsample_bytree': 0.9086581455128002}. Best is trial 0 with value: 0.047329189342549816.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:36:57] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:36:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:36:59] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:36:59,148] Trial 3 finished with value: 0.15163395321245265 and parameters: {'max_depth': 4, 'learning_rate': 0.01247196579179291, 'n_estimators': 163, 'min_child_weight': 1, 'subsample': 0.6371179250715039, 'colsample_bytree': 0.8612625527973957}. Best is trial 0 with value: 0.047329189342549816.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:36:59] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:36:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:01] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:01,491] Trial 4 finished with value: 0.08606948492429911 and parameters: {'max_depth': 5, 'learning_rate': 0.04485299311134326, 'n_estimators': 77, 'min_child_weight': 2, 'subsample': 0.67647578767156, 'colsample_bytree': 0.9853795016640519}. Best is trial 0 with value: 0.047329189342549816.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:01] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:05] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:05,964] Trial 5 finished with value: 0.06791158339996384 and parameters: {'max_depth': 7, 'learning_rate': 0.049162685629973585, 'n_estimators': 199, 'min_child_weight': 2, 'subsample': 0.7633172751646068, 'colsample_bytree': 0.7405583185145371}. Best is trial 0 with value: 0.047329189342549816.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:05] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:07] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:07,053] Trial 6 finished with value: 0.06112816280209432 and parameters: {'max_depth': 3, 'learning_rate': 0.26407704877860794, 'n_estimators': 73, 'min_child_weight': 1, 'subsample': 0.7137537969423985, 'colsample_bytree': 0.6231212300389745}. Best is trial 0 with value: 0.047329189342549816.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:07] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:11] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:11,746] Trial 7 finished with value: 0.08410925691883109 and parameters: {'max_depth': 7, 'learning_rate': 0.025382590528808063, 'n_estimators': 99, 'min_child_weight': 2, 'subsample': 0.9124465712796791, 'colsample_bytree': 0.7101387851617401}. Best is trial 0 with value: 0.047329189342549816.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:11] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:15] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:16,028] Trial 8 finished with value: 0.049212039926749385 and parameters: {'max_depth': 7, 'learning_rate': 0.10943204414719883, 'n_estimators': 120, 'min_child_weight': 5, 'subsample': 0.9130085925606478, 'colsample_bytree': 0.8604759595046929}. Best is trial 0 with value: 0.047329189342549816.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:16] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:19] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:19,209] Trial 9 finished with value: 0.045007866704495636 and parameters: {'max_depth': 6, 'learning_rate': 0.22442814282634682, 'n_estimators': 186, 'min_child_weight': 1, 'subsample': 0.6484250513813391, 'colsample_bytree': 0.9777502163037948}. Best is trial 9 with value: 0.045007866704495636.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:19] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:22] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:22,257] Trial 10 finished with value: 0.04299605375151527 and parameters: {'max_depth': 6, 'learning_rate': 0.29148423937381956, 'n_estimators': 152, 'min_child_weight': 3, 'subsample': 0.6004033917430832, 'colsample_bytree': 0.9975286167618971}. Best is trial 10 with value: 0.04299605375151527.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:22] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:25] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:25,609] Trial 11 finished with value: 0.04139692037863352 and parameters: {'max_depth': 6, 'learning_rate': 0.29852211087496444, 'n_estimators': 154, 'min_child_weight': 3, 'subsample': 0.6076223262004115, 'colsample_bytree': 0.9930561542678242}. Best is trial 11 with value: 0.04139692037863352.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:25] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:28] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:28,892] Trial 12 finished with value: 0.04714864202625679 and parameters: {'max_depth': 6, 'learning_rate': 0.17570353827598528, 'n_estimators': 149, 'min_child_weight': 3, 'subsample': 0.6033083687777298, 'colsample_bytree': 0.9341208496081322}. Best is trial 11 with value: 0.04139692037863352.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:28] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:31] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:31,993] Trial 13 finished with value: 0.042738129013953685 and parameters: {'max_depth': 6, 'learning_rate': 0.2919288819784522, 'n_estimators': 142, 'min_child_weight': 3, 'subsample': 0.6052561232297319, 'colsample_bytree': 0.9964090669582713}. Best is trial 11 with value: 0.04139692037863352.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:32] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:33] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:33,631] Trial 14 finished with value: 0.07993087617033345 and parameters: {'max_depth': 4, 'learning_rate': 0.0801985854395654, 'n_estimators': 127, 'min_child_weight': 4, 'subsample': 0.7720318167389356, 'colsample_bytree': 0.9286216016766339}. Best is trial 11 with value: 0.04139692037863352.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:33] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:35] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:35,712] Trial 15 finished with value: 0.05413840241417556 and parameters: {'max_depth': 5, 'learning_rate': 0.16240213114648877, 'n_estimators': 128, 'min_child_weight': 4, 'subsample': 0.9859458446205245, 'colsample_bytree': 0.7913742118040151}. Best is trial 11 with value: 0.04139692037863352.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:35] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:37] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:37,890] Trial 16 finished with value: 0.050450078667044984 and parameters: {'max_depth': 5, 'learning_rate': 0.19861780020097447, 'n_estimators': 145, 'min_child_weight': 3, 'subsample': 0.7047035941286024, 'colsample_bytree': 0.9448372134806731}. Best is trial 11 with value: 0.04139692037863352.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:37] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:42,370] Trial 17 finished with value: 0.0670346392922545 and parameters: {'max_depth': 6, 'learning_rate': 0.06900487070218383, 'n_estimators': 166, 'min_child_weight': 3, 'subsample': 0.6732897605961484, 'colsample_bytree': 0.8854882038189362}. Best is trial 11 with value: 0.04139692037863352.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:44] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:44,105] Trial 18 finished with value: 0.10807046503830187 and parameters: {'max_depth': 4, 'learning_rate': 0.0354713875403399, 'n_estimators': 111, 'min_child_weight': 4, 'subsample': 0.8263017300776345, 'colsample_bytree': 0.8011797015425964}. Best is trial 11 with value: 0.04139692037863352.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:44] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:47] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:47,241] Trial 19 finished with value: 0.04199014727502515 and parameters: {'max_depth': 6, 'learning_rate': 0.2888122094580436, 'n_estimators': 135, 'min_child_weight': 2, 'subsample': 0.6320610122116439, 'colsample_bytree': 0.9475691008838883}. Best is trial 11 with value: 0.04139692037863352.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:47] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:48] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:48,461] Trial 20 finished with value: 0.08049831059296897 and parameters: {'max_depth': 3, 'learning_rate': 0.12410777384797901, 'n_estimators': 133, 'min_child_weight': 2, 'subsample': 0.7504492512802501, 'colsample_bytree': 0.961640985562844}. Best is trial 11 with value: 0.04139692037863352.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:48] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:51] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:37:51,546] Trial 21 finished with value: 0.04297026127775916 and parameters: {'max_depth': 6, 'learning_rate': 0.28721283156216065, 'n_estimators': 142, 'min_child_weight': 2, 'subsample': 0.6361142205732685, 'colsample_bytree': 0.9589233287478102}. Best is trial 11 with value: 0.04139692037863352.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:51] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:37:54] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# ...
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:39:11,442] Trial 42 finished with value: 0.03974620205823942 and parameters: {'max_depth': 7, 'learning_rate': 0.24991784485674143, 'n_estimators': 58, 'min_child_weight': 5, 'subsample': 0.7545383653439538, 'colsample_bytree': 0.7472033814217179}. Best is trial 23 with value: 0.03832761600165069.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:11] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:15] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:39:15,124] Trial 43 finished with value: 0.043279770962833086 and parameters: {'max_depth': 7, 'learning_rate': 0.17967653497964756, 'n_estimators': 61, 'min_child_weight': 5, 'subsample': 0.777910446614519, 'colsample_bytree': 0.6503642323631036}. Best is trial 23 with value: 0.03832761600165069.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:15] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:18] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:39:18,718] Trial 44 finished with value: 0.040519976270924185 and parameters: {'max_depth': 7, 'learning_rate': 0.24971348160023507, 'n_estimators': 58, 'min_child_weight': 5, 'subsample': 0.8148798707827786, 'colsample_bytree': 0.7303591540260694}. Best is trial 23 with value: 0.03832761600165069.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:18] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:21] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:39:21,972] Trial 45 finished with value: 0.08227799128214386 and parameters: {'max_depth': 6, 'learning_rate': 0.03656241303363597, 'n_estimators': 50, 'min_child_weight': 5, 'subsample': 0.6632198947644627, 'colsample_bytree': 0.7228619502881718}. Best is trial 23 with value: 0.03832761600165069.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:22] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:25] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:39:25,796] Trial 46 finished with value: 0.04033942895463105 and parameters: {'max_depth': 7, 'learning_rate': 0.24866469441654118, 'n_estimators': 75, 'min_child_weight': 5, 'subsample': 0.8253828539769104, 'colsample_bytree': 0.6981344492521626}. Best is trial 23 with value: 0.03832761600165069.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:25] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:30] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:39:30,103] Trial 47 finished with value: 0.04162905264243899 and parameters: {'max_depth': 7, 'learning_rate': 0.20455222333927858, 'n_estimators': 79, 'min_child_weight': 5, 'subsample': 0.8732280811032096, 'colsample_bytree': 0.6993845362367942}. Best is trial 23 with value: 0.03832761600165069.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:30] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:32] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:39:32,474] Trial 48 finished with value: 0.06631245002708208 and parameters: {'max_depth': 5, 'learning_rate': 0.09291507681917983, 'n_estimators': 73, 'min_child_weight': 4, 'subsample': 0.7177133825465413, 'colsample_bytree': 0.6758649959472752}. Best is trial 23 with value: 0.03832761600165069.
# <ipython-input-14-a5278311f9e4>:34: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.3),
# <ipython-input-14-a5278311f9e4>:37: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-14-a5278311f9e4>:38: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:32] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:35] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-09-05 01:39:35,734] Trial 49 finished with value: 0.07067137809187274 and parameters: {'max_depth': 6, 'learning_rate': 0.05771017361106748, 'n_estimators': 68, 'min_child_weight': 5, 'subsample': 0.9019471812545209, 'colsample_bytree': 0.6038933962339308}. Best is trial 23 with value: 0.03832761600165069.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [01:39:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Number of finished trials: 50
# Best trial:
#   Value: 0.03832761600165069
#   Params:
#     max_depth: 7
#     learning_rate: 0.29958224463052163
#     n_estimators: 112
#     min_child_weight: 3
#     subsample: 0.6642838225971721
#     colsample_bytree: 0.9861864474421846
# Training Accuracy: 0.9725
# Testing Accuracy: 0.9607
# Email: Get rich quick! Buy our amazing product now!
# Classification: Spam
#
# Email: Hi John, can we reschedule our meeting to next week?
# Classification: Ham
#
# Email: Congratulations! You've won a free iPhone. Click here to claim.
# Classification: Spam
#
# Email: Please find attached the report for Q2 sales figures.
# Classification: Ham

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Convert test_preds to binary format
test_preds_binary = (test_preds > 0.5).astype(int)

# Generate and print classification report
print("\nClassification Report:")
print(classification_report(y_test, test_preds_binary, target_names=['Ham', 'Spam']))

# Generate and print confusion matrix
cm = confusion_matrix(y_test, test_preds_binary)
print("\nConfusion Matrix:")
print(cm)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          Ham       0.98      0.94      0.96     20467
#         Spam       0.94      0.98      0.96     18304
#
#     accuracy                           0.96     38771
#    macro avg       0.96      0.96      0.96     38771
# weighted avg       0.96      0.96      0.96     38771
#
#
# Confusion Matrix:
# [[19290  1177]
#  [  400 17904]]

# %%
from google.colab import drive
drive.mount('/content/drive')
